# %% [markdown]
# # Setup

# %%
# Install and import necessary packages and libraries
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.metrics import classification_report, precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization,Input, LSTM, Bidirectional
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
# Version information
print("Versions of imported packages:")
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
print(f"seaborn: {sns.__version__}")
print(f"matplotlib: {plt.matplotlib.__version__}")
print(f"tensorflow: {tf.__version__}")
print(f"scikit-learn: {tf.__version__}")
# Out:
# Versions of imported packages:
# Num GPUs Available:  1
# numpy: 1.24.3
# pandas: 2.0.3
# seaborn: 0.13.2
# matplotlib: 3.7.2
# tensorflow: 2.10.0
# scikit-learn: 2.10.0

# %% [markdown]
# # Loading Data

# %%
# loading data
with open('data/emnist_train.pkl', 'rb') as f:
    train_data = pickle.load(f)
with open('data/emnist_test.pkl', 'rb') as f:
    test_data = pickle.load(f)

x_train = train_data['data']
y_train = train_data['labels']

x_test = test_data['data']
y_test = test_data['labels']

print("Training data:", x_train.shape)
print("Training labels:", y_train.shape)
print("Test data:", x_test.shape)
print("Test labels:", y_test.shape)
# Out:
# Training data: (100000, 28, 28)
# Training labels: (100000,)
# Test data: (20000, 28, 28)
# Test labels: (20000,)

# %%
# show some data
fig, axes = plt.subplots(2, 5, figsize=(10, 5))  # 2 rows and 5 columns displaying 10 images

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap='gray')  # Display the ith image, using greyscale colour mapping
    ax.set_title(f"Label: {y_train[i]}")  # Showing corresponding tags
    ax.axis('off')  # no axes

plt.tight_layout()  
plt.show()

# %% [markdown]
# # Pre-processing

# %%
def preprocess_data(x_train, y_train, x_test, y_test, num_classes=62, validation_split=0.2, one_hot_encode=True):

    # Reshape training and test data for grayscale: (num_samples, 28, 28, 1)
    x_train = x_train.reshape(-1, 28, 28, 1).astype('float32')
    x_test = x_test.reshape(-1, 28, 28, 1).astype('float32')
    
    # Normalize the training and test data 
    x_train = x_train / 255.0
    x_test = x_test / 255.0
    
    # Optional One-hot coded labels
    if one_hot_encode:
        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

    # split the data into training and validation sets
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_split, random_state=42)
    
    # show the results
    print("\nAfter preprocessing:")
    print(f"x_train shape: {x_train.shape}")
    print(f"y_train shape: {y_train.shape}")
    print(f"x_val shape: {x_val.shape}")
    print(f"y_val shape: {y_val.shape}")
    print(f"x_test shape: {x_test.shape}")
    print(f"y_test shape: {y_test.shape}")
    
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
# EMNIST has 62 classes
num_classes=62

# %% [markdown]
# # Model Implementation

# %% [markdown]
# ## Model 1: Convolutional Neural Network (CNN)

# %% [markdown]
# ### Model Implementation

# %%
# Getting pre-processed data
x_train_cnn, y_train_cnn, x_val_cnn, y_val_cnn, x_test_cnn, y_test_cnn = preprocess_data(x_train, y_train, x_test, y_test, one_hot_encode=True)
# Out:
# After preprocessing:
# x_train shape: (80000, 28, 28, 1)
# y_train shape: (80000, 62)
# x_val shape: (20000, 28, 28, 1)
# y_val shape: (20000, 62)
# x_test shape: (20000, 28, 28, 1)
# y_test shape: (20000, 62)

# %%
# Data augmentation setup
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# Fit the datagen on the training data
datagen.fit(x_train_cnn)

print("\nData augmentation generator is ready to use during model training.")
# Out:
# Data augmentation generator is ready to use during model training.

# %%
# Model Implementation

model_cnn = Sequential()

# Convolutional Layer 1
model_cnn.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))
model_cnn.add(BatchNormalization())

# Convolutional Layer 2
model_cnn.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))
model_cnn.add(BatchNormalization())

# Flatten and Dense Layers
model_cnn.add(Flatten())
model_cnn.add(Dense(128, activation='relu'))
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(num_classes, activation='softmax'))

# Compile the model
model_cnn.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 13, 13, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 5, 5, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 62)                7998
#
# =================================================================
# Total params: 232,126
# Trainable params: 231,934
# Non-trainable params: 192
# _________________________________________________________________

# %%
# Function to create model, required for KerasClassifier
def create_cnn_model(optimizer='adam', dropout_rate=0.5):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ### Hyperparameter Tunning

# %%
# Hyperparameter tuning for the CNN model
# Wrap the model using the function you have created
model_cnn_cv = KerasClassifier(build_fn=create_cnn_model, verbose=0)

# Define the grid search parameters
param_grid = {
    'batch_size': [64, 128],
    'epochs': [5],  # Set to a low number for demonstration purposes
    'optimizer': ['adam', 'rmsprop'],
    'dropout_rate': [0.3, 0.5]
}

# %%
# Create Grid Search
grid_cnn = GridSearchCV(estimator=model_cnn_cv, param_grid=param_grid, n_jobs=1, cv=3)

# Fit the grid search
# Note: This process will take a considerable amount of time
grid_result_cnn = grid_cnn.fit(x_train_cnn, y_train_cnn)

# Summarize results
print("Best: %f using %s" % (grid_result_cnn.best_score_, grid_result_cnn.best_params_))
# Out:
# Best: 0.841625 using {'batch_size': 128, 'dropout_rate': 0.3, 'epochs': 5, 'optimizer': 'adam'}

# %%
# Extract the best parameters
# best_params_cnn = grid_result_cnn.best_params_
best_params_cnn = {'batch_size': 128, 'dropout_rate': 0.3, 'epochs': 5, 'optimizer': 'adam'}
print("Best Parameters:", best_params_cnn)

# Create a new model with the best parameters
model_cnn_best = create_cnn_model(optimizer=best_params_cnn['optimizer'], dropout_rate=best_params_cnn['dropout_rate'])

# Train the model with the training data
history_cnn = model_cnn_best.fit(
    x_train_cnn, y_train_cnn,
    batch_size=best_params_cnn['batch_size'],
    epochs=20,  # Increase the number of epochs for better performance
    validation_split=0.1,
    verbose=1
)
# Out:
# Best Parameters: {'batch_size': 128, 'dropout_rate': 0.3, 'epochs': 5, 'optimizer': 'adam'}
# Epoch 1/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.9699 - accuracy: 0.7195 - val_loss: 0.7900 - val_accuracy: 0.7527
# Epoch 2/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.5687 - accuracy: 0.8114 - val_loss: 0.4953 - val_accuracy: 0.8366
# Epoch 3/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4890 - accuracy: 0.8308 - val_loss: 0.4632 - val_accuracy: 0.8371
# Epoch 4/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4469 - accuracy: 0.8406 - val_loss: 0.4505 - val_accuracy: 0.8395
# Epoch 5/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4170 - accuracy: 0.8480 - val_loss: 0.4417 - val_accuracy: 0.8474
# Epoch 6/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3945 - accuracy: 0.8558 - val_loss: 0.4332 - val_accuracy: 0.8490
# Epoch 7/20
# 563/563 [==============================] - 1s 3ms/step - loss: 0.3745 - accuracy: 0.8600 - val_loss: 0.4460 - val_accuracy: 0.8478
# Epoch 8/20
# 563/563 [==============================] - 1s 3ms/step - loss: 0.3585 - accuracy: 0.8636 - val_loss: 0.4502 - val_accuracy: 0.8464
# Epoch 9/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3401 - accuracy: 0.8702 - val_loss: 0.4492 - val_accuracy: 0.8459
# Epoch 10/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3285 - accuracy: 0.8730 - val_loss: 0.4565 - val_accuracy: 0.8456
# Epoch 11/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3167 - accuracy: 0.8776 - val_loss: 0.4468 - val_accuracy: 0.8471
# Epoch 12/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3023 - accuracy: 0.8822 - val_loss: 0.4780 - val_accuracy: 0.8454
# Epoch 13/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2913 - accuracy: 0.8862 - val_loss: 0.4770 - val_accuracy: 0.8444
# Epoch 14/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2831 - accuracy: 0.8877 - val_loss: 0.4957 - val_accuracy: 0.8471
# Epoch 15/20
# 563/563 [==============================] - 1s 3ms/step - loss: 0.2732 - accuracy: 0.8944 - val_loss: 0.4994 - val_accuracy: 0.8435
# Epoch 16/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2624 - accuracy: 0.8963 - val_loss: 0.5035 - val_accuracy: 0.8505
# Epoch 17/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2561 - accuracy: 0.8992 - val_loss: 0.5156 - val_accuracy: 0.8481
# Epoch 18/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2448 - accuracy: 0.9039 - val_loss: 0.5365 - val_accuracy: 0.8440
# Epoch 19/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2389 - accuracy: 0.9053 - val_loss: 0.5407 - val_accuracy: 0.8372
# Epoch 20/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2315 - accuracy: 0.9097 - val_loss: 0.5661 - val_accuracy: 0.8445

# %% [markdown]
# ## Model 2: RNN

# %% [markdown]
# ### Model Implementation

# %%
# Getting pre-processed data
x_train_rnn, y_train_rnn, x_val_rnn, y_val_rnn, x_test_rnn, y_test_rnn = preprocess_data(x_train, y_train, x_test, y_test, one_hot_encode=True)
# Out:
# After preprocessing:
# x_train shape: (80000, 28, 28, 1)
# y_train shape: (80000, 62)
# x_val shape: (20000, 28, 28, 1)
# y_val shape: (20000, 62)
# x_test shape: (20000, 28, 28, 1)
# y_test shape: (20000, 62)

# %%
# Design RNN Model
def create_rnn_model(learning_rate=0.001, units=128, recurrent_units=64, dropout_rate=0.5):
    model = Sequential()
    model.add(Input(shape=(28, 28)))
    # LSTM1
    model.add(Bidirectional(LSTM(units, return_sequences=True)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    # LSTM2
    model.add(LSTM(recurrent_units, return_sequences=False))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    # Dense
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(dropout_rate))
    # Output
    model.add(Dense(62, activation='softmax'))
    # Compile
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ### Hyperparameter Tunning

# %%
rnn_model = KerasClassifier(build_fn=create_rnn_model, verbose=0)
param_grid_rnn = {
    'batch_size': [64, 128],
    'units': [128, 256],
    'recurrent_units': [64, 128],
    'dropout_rate': [0.3, 0.5],
}

# %%
grid_search_rnn = GridSearchCV(estimator=rnn_model, param_grid=param_grid_rnn, cv=3, verbose=2, n_jobs=1)
grid_result_rnn = grid_search_rnn.fit(x_train_rnn, y_train_rnn)
print(f"best params: {grid_result_rnn.best_params_}")
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=64, units=128; total time=  15.2s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=64, units=128; total time=  26.2s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=64, units=128; total time=  19.5s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=64, units=256; total time=  14.1s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=64, units=256; total time=  14.1s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=64, units=256; total time=  14.1s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=128, units=128; total time=  14.4s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=128, units=128; total time=  14.3s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=128, units=128; total time=  14.3s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=128, units=256; total time=  14.3s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=128, units=256; total time=  14.4s
# [CV] END batch_size=64, dropout_rate=0.3, recurrent_units=128, units=256; total time=  14.8s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=64, units=128; total time=  13.9s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=64, units=128; total time=  14.1s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=64, units=128; total time=  13.9s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=64, units=256; total time=  14.4s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=64, units=256; total time=  14.2s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=64, units=256; total time=  14.1s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=128, units=128; total time=  14.6s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=128, units=128; total time=  14.6s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=128, units=128; total time=  14.8s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=128, units=256; total time=  14.7s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=128, units=256; total time=  15.4s
# [CV] END batch_size=64, dropout_rate=0.5, recurrent_units=128, units=256; total time=  15.6s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=64, units=128; total time=   9.1s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=64, units=128; total time=   8.9s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=64, units=128; total time=   8.8s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=64, units=256; total time=   9.2s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=64, units=256; total time=   9.2s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=64, units=256; total time=   9.3s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=128, units=128; total time=   9.1s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=128, units=128; total time=   9.4s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=128, units=128; total time=   9.7s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=128, units=256; total time=   9.2s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=128, units=256; total time=   9.1s
# [CV] END batch_size=128, dropout_rate=0.3, recurrent_units=128, units=256; total time=   9.4s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=64, units=128; total time=   8.9s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=64, units=128; total time=   9.0s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=64, units=128; total time=   9.5s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=64, units=256; total time=   9.3s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=64, units=256; total time=   9.2s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=64, units=256; total time=   9.0s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=128, units=128; total time=   9.3s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=128, units=128; total time=   9.2s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=128, units=128; total time=   9.3s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=128, units=256; total time=   9.2s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=128, units=256; total time=   9.3s
# [CV] END batch_size=128, dropout_rate=0.5, recurrent_units=128, units=256; total time=   9.2s
# best params: {'batch_size': 64, 'dropout_rate': 0.3, 'recurrent_units': 128, 'units': 128}

# %%
# best_params_rnn = grid_result_rnn.best_params_
best_params_rnn = {'batch_size': 64, 'dropout_rate': 0.3, 'recurrent_units': 128, 'units': 128,'learning_rate': 0.001, 'epochs': 20}
best_rnn = create_rnn_model(learning_rate=best_params_rnn['learning_rate'])
best_rnn.summary()
history_rnn = best_rnn.fit(x_train_rnn, y_train_rnn,
                          validation_data=(x_val_rnn, y_val_rnn),
                          epochs=best_params_rnn['epochs'],
                          batch_size=best_params_rnn['batch_size'])
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 28, 256)          160768
#  nal)
#
#  batch_normalization_14 (Bat  (None, 28, 256)          1024
#  chNormalization)
#
#  dropout_27 (Dropout)        (None, 28, 256)           0
#
#  lstm_5 (LSTM)               (None, 64)                82176
#
#  batch_normalization_15 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 128)               8320
#
#  dropout_29 (Dropout)        (None, 128)               0
#
#  dense_35 (Dense)            (None, 62)                7998
#
# =================================================================
# Total params: 260,542
# Trainable params: 259,902
# Non-trainable params: 640
# _________________________________________________________________
# Epoch 1/20
# 1250/1250 [==============================] - 18s 13ms/step - loss: 1.9571 - accuracy: 0.4932 - val_loss: 1.0505 - val_accuracy: 0.6770
# Epoch 2/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.1179 - accuracy: 0.6722 - val_loss: 0.7250 - val_accuracy: 0.7603
# Epoch 3/20
# 1250/1250 [==============================] - 14s 12ms/step - loss: 0.9183 - accuracy: 0.7224 - val_loss: 0.6739 - val_accuracy: 0.7805
# Epoch 4/20
# 1250/1250 [==============================] - 14s 11ms/step - loss: 0.8108 - accuracy: 0.7520 - val_loss: 0.5951 - val_accuracy: 0.7954
# Epoch 5/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.7459 - accuracy: 0.7699 - val_loss: 0.5720 - val_accuracy: 0.8080
# Epoch 6/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.6957 - accuracy: 0.7835 - val_loss: 0.5583 - val_accuracy: 0.8105
# Epoch 7/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.6670 - accuracy: 0.7910 - val_loss: 0.5519 - val_accuracy: 0.8167
# Epoch 8/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.6381 - accuracy: 0.7982 - val_loss: 0.5390 - val_accuracy: 0.8224
# Epoch 9/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.6135 - accuracy: 0.8065 - val_loss: 0.5209 - val_accuracy: 0.8257
# Epoch 10/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5993 - accuracy: 0.8089 - val_loss: 0.5230 - val_accuracy: 0.8219
# Epoch 11/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5807 - accuracy: 0.8146 - val_loss: 0.5217 - val_accuracy: 0.8267
# Epoch 12/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5648 - accuracy: 0.8184 - val_loss: 0.5332 - val_accuracy: 0.8248
# Epoch 13/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5569 - accuracy: 0.8200 - val_loss: 0.5034 - val_accuracy: 0.8325
# Epoch 14/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5426 - accuracy: 0.8232 - val_loss: 0.4985 - val_accuracy: 0.8331
# Epoch 15/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5291 - accuracy: 0.8267 - val_loss: 0.5190 - val_accuracy: 0.8316
# Epoch 16/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5266 - accuracy: 0.8288 - val_loss: 0.5187 - val_accuracy: 0.8301
# Epoch 17/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5143 - accuracy: 0.8321 - val_loss: 0.5119 - val_accuracy: 0.8350
# Epoch 18/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5028 - accuracy: 0.8348 - val_loss: 0.5136 - val_accuracy: 0.8368
# Epoch 19/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.4992 - accuracy: 0.8356 - val_loss: 0.5085 - val_accuracy: 0.8352
# Epoch 20/20
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.4875 - accuracy: 0.8384 - val_loss: 0.5144 - val_accuracy: 0.8339

# %% [markdown]
# ## Model 3: Transformer

# %% [markdown]
# ### Model Implementation

# %%
# Getting pre-processed data
x_train_vit, y_train_vit, x_val_vit, y_val_vit, x_test_vit, y_test_vit = preprocess_data(x_train, y_train, x_test, y_test, one_hot_encode=False)
# Out:
# After preprocessing:
# x_train shape: (80000, 28, 28, 1)
# y_train shape: (80000,)
# x_val shape: (20000, 28, 28, 1)
# y_val shape: (20000,)
# x_test shape: (20000, 28, 28, 1)
# y_test shape: (20000,)

# %%
# Implementation vision transformer
class vit(Model):
    def __init__(self, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, dropout):
        super(vit, self).__init__()

        # Calculate the total number of patches in the image
        # If the image size is 28x28 and the patch size is 4, then num_patches = (28 // 4) ** 2 = 49
        assert image_size % patch_size == 0, "Image size must be divisible by patch size"
        num_patches = (image_size // patch_size) ** 2
        patch_dim = patch_size * patch_size  # Number of pixels per patch

        # Patch embedding layer: transforms each patch into a dim-dimensional feature vector
        self.patch_embedding = layers.Dense(dim)
        
        # Location embedding for learning the relative position of each patch in the image
        self.position_embedding = layers.Embedding(input_dim=num_patches + 1, output_dim=dim)
        
        # Classification token (class token) to indicate the class of the image; randomly initialised to a trainable variable
        self.cls_token = tf.Variable(tf.zeros([1, 1, dim]), trainable=True)

        # Transformer coding layers
        # Each transformer layer contains a MultiHeadAttention mechanism, a Layer Normalisation Layer and an MLP Layer
        # layers.MultiHeadAttention performs multi-head self-attention computation
        self.transformer_layers = [
            layers.MultiHeadAttention(num_heads=heads, key_dim=dim, dropout=dropout) for _ in range(depth)
        ]
        
        # Layer normalisation before each transformer layer
        self.norm_layers = [layers.LayerNormalization(epsilon=1e-6) for _ in range(depth)]
        
        # Small MLP networks behind each transformer layer
        self.mlp_layers = [tf.keras.Sequential([
            layers.Dense(mlp_dim, activation='relu'),  # Hidden Layers for MLP
            layers.Dropout(dropout),                   # Dropout prevents overfitting
            layers.Dense(dim),                         # Output to dim dimension for easy residual linking
            layers.Dropout(dropout)
        ]) for _ in range(depth)]

        # Category header: output scores for each category
        self.mlp_head = tf.keras.Sequential([
            layers.LayerNormalization(epsilon=1e-6),   # Layer normalisation before output
            layers.Dense(num_classes)                  # Output layer with dimension num_classes
        ])

    def call(self, x):
        # Get batch size
        batch_size = tf.shape(x)[0]
        
        # Divide the input image into patches
        patches = tf.image.extract_patches(
            images=x,
            sizes=[1, 4, 4, 1],          
            strides=[1, 4, 4, 1],        
            rates=[1, 1, 1, 1],
            padding='VALID'
        )
        patches = tf.reshape(patches, [batch_size, -1, 4 * 4])  # Flatten each patch into one dimension

        # Apply patch embedding to transform each patch into a dim-dimensional feature vector
        x = self.patch_embedding(patches)

        # Extend the size of the classification markers to the batch
        cls_tokens = tf.repeat(self.cls_token, repeats=batch_size, axis=0)
        
        # Splice classification markers in front of patch features
        x = tf.concat([cls_tokens, x], axis=1)
        
        # Add positional embedding to indicate the relative position of each patch
        positions = tf.range(start=0, limit=tf.shape(x)[1], delta=1)
        x += self.position_embedding(positions)

        # Transformer encoder part
        # Each transformer layer undergoes a layer of normalisation, a multi-head attention mechanism, and an MLP layer
        for norm_layer, transformer_layer, mlp_layer in zip(self.norm_layers, self.transformer_layers, self.mlp_layers):
            x = norm_layer(x)
            x = transformer_layer(x, x) + x
            x = mlp_layer(x) + x

        # Classification predictions using only classified labelled features
        x = x[:, 0]  
        return self.mlp_head(x)

# %%
# Construct the Vision Transformer model and compile it.
def build_vit_model(image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, dropout):
    model = vit(image_size=image_size, 
                patch_size=patch_size, 
                num_classes=num_classes, 
                dim=dim, 
                depth=depth, 
                heads=heads, 
                mlp_dim=mlp_dim, 
                dropout=dropout)
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),  
                  metrics=['accuracy'])
    return model

# %%
# Model testing with given parameters
test_model_vit = build_vit_model(image_size=28, patch_size=4, num_classes=num_classes, dim=64, depth=4, heads=4, mlp_dim=128, dropout=0.1)

test_model_vit.fit(x_train_vit, y_train_vit, batch_size=64, epochs=10, validation_data=(x_val_vit, y_val_vit))
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 16s 12ms/step - loss: 1.6962 - accuracy: 0.5297 - val_loss: 0.9745 - val_accuracy: 0.6914
# Epoch 2/10
# 1250/1250 [==============================] - 14s 11ms/step - loss: 0.8824 - accuracy: 0.7218 - val_loss: 0.7341 - val_accuracy: 0.7558
# Epoch 3/10
# 1250/1250 [==============================] - 14s 11ms/step - loss: 0.7293 - accuracy: 0.7622 - val_loss: 0.6431 - val_accuracy: 0.7834
# Epoch 4/10
# 1250/1250 [==============================] - 14s 12ms/step - loss: 0.6610 - accuracy: 0.7789 - val_loss: 0.5986 - val_accuracy: 0.7959
# Epoch 5/10
# 1250/1250 [==============================] - 14s 12ms/step - loss: 0.6166 - accuracy: 0.7910 - val_loss: 0.5891 - val_accuracy: 0.8002
# Epoch 6/10
# 1250/1250 [==============================] - 14s 12ms/step - loss: 0.5898 - accuracy: 0.7994 - val_loss: 0.5534 - val_accuracy: 0.8086
# Epoch 7/10
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5580 - accuracy: 0.8069 - val_loss: 0.5446 - val_accuracy: 0.8105
# Epoch 8/10
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5429 - accuracy: 0.8123 - val_loss: 0.5118 - val_accuracy: 0.8192
# Epoch 9/10
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5288 - accuracy: 0.8158 - val_loss: 0.5481 - val_accuracy: 0.8092
# Epoch 10/10
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5162 - accuracy: 0.8186 - val_loss: 0.5146 - val_accuracy: 0.8203

# %%
# Display the results of the test
train_loss_test_vit, train_accuracy_test_vit = test_model_vit.evaluate(x_train_vit, y_train_vit)
val_loss_test_vit, val_accuracy_test_vit = test_model_vit.evaluate(x_val_vit, y_val_vit)

print(f"Train Loss: {train_loss_test_vit:.4f}, Train Accuracy: {train_accuracy_test_vit:.4f}")
print(f"Validation Loss: {val_loss_test_vit:.4f}, Validation Accuracy: {val_accuracy_test_vit:.4f}")
# Out:
# 2500/2500 [==============================] - 16s 7ms/step - loss: 0.4356 - accuracy: 0.8430
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5005 - accuracy: 0.8255
# Train Loss: 0.4356, Train Accuracy: 0.8430
# Validation Loss: 0.5005, Validation Accuracy: 0.8255

# %% [markdown]
# ### Hyperparameter Tunning

# %%
# Wrapping the build_vit_model function with KerasClassifier for compatibility with scikit-learn's RandomisedSearchCV
model_vit = KerasClassifier(build_fn=build_vit_model, epochs=5, batch_size=64, verbose=0)

# Defining the Hyperparameter
param_dist_vit = {
    'image_size': [28],
    'patch_size': [2, 4, 7],
    'num_classes':[62],
    'dim': [32, 64, 128],
    'depth': [4, 6, 8],
    'heads': [4, 8],
    'mlp_dim': [64, 128, 256],
    'dropout': [0.1, 0.2, 0.3]
}

# Use Randomized Search + Cross-Validation
random_search_vit = RandomizedSearchCV(
    estimator=model_vit,
    param_distributions=param_dist_vit,
    n_iter=10,
    scoring='accuracy',
    cv=3
)

# %%
random_search_vit.fit(x_train_vit, y_train_vit)

print("Best Parameters:", random_search_vit.best_params_)
print("Best Score:", random_search_vit.best_score_)
# Out:
# 834/834 [==============================] - 9s 10ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 7s 8ms/step
# 834/834 [==============================] - 7s 8ms/step
# 834/834 [==============================] - 7s 7ms/step
# 834/834 [==============================] - 6s 7ms/step
# 834/834 [==============================] - 6s 7ms/step
# 834/834 [==============================] - 6s 7ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 5s 5ms/step
# 834/834 [==============================] - 5s 5ms/step
# 834/834 [==============================] - 5s 5ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 8s 9ms/step
# 834/834 [==============================] - 5s 6ms/step
# 834/834 [==============================] - 5s 6ms/step
# 834/834 [==============================] - 5s 6ms/step
# 834/834 [==============================] - 7s 8ms/step
# 834/834 [==============================] - 7s 7ms/step
# 834/834 [==============================] - 7s 8ms/step
# 834/834 [==============================] - 5s 5ms/step
# 834/834 [==============================] - 5s 5ms/step
# 834/834 [==============================] - 5s 5ms/step
# 834/834 [==============================] - 7s 8ms/step
# 834/834 [==============================] - 7s 8ms/step
# 834/834 [==============================] - 7s 8ms/step
# Best Parameters: {'patch_size': 4, 'num_classes': 62, 'mlp_dim': 256, 'image_size': 28, 'heads': 4, 'dropout': 0.2, 'dim': 128, 'depth': 4}
# Best Score: 0.7580751247697082

# %%
best_params_vit = {'patch_size': 4, 'num_classes': 62, 'mlp_dim': 256, 'image_size': 28, 'heads': 4, 'dropout': 0.2, 'dim': 128, 'depth': 4}

# Create a new model with the best parameters
final_model_vit = build_vit_model(
    image_size=best_params_vit['image_size'],
    patch_size=best_params_vit['patch_size'],
    num_classes=best_params_vit['num_classes'],
    dim=best_params_vit['dim'],
    depth=best_params_vit['depth'],
    heads=best_params_vit['heads'],
    mlp_dim=best_params_vit['mlp_dim'],
    dropout=best_params_vit['dropout']
)

# Train the model with the training data
history_vit = final_model_vit.fit(
    x_train_vit, y_train_vit,
    batch_size=64,
    epochs=20,  
    validation_data=(x_val_vit, y_val_vit)
)
# Out:
# Epoch 1/20
# 1250/1250 [==============================] - 18s 13ms/step - loss: 1.6389 - accuracy: 0.5373 - val_loss: 1.1185 - val_accuracy: 0.6550
# Epoch 2/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.9665 - accuracy: 0.6963 - val_loss: 0.8972 - val_accuracy: 0.7142
# Epoch 3/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.8242 - accuracy: 0.7351 - val_loss: 0.6936 - val_accuracy: 0.7640
# Epoch 4/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.7439 - accuracy: 0.7539 - val_loss: 0.6865 - val_accuracy: 0.7744
# Epoch 5/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.6926 - accuracy: 0.7690 - val_loss: 0.6823 - val_accuracy: 0.7697
# Epoch 6/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.6560 - accuracy: 0.7799 - val_loss: 0.5826 - val_accuracy: 0.7969
# Epoch 7/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.6239 - accuracy: 0.7871 - val_loss: 0.6048 - val_accuracy: 0.7929
# Epoch 8/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 0.6022 - accuracy: 0.7951 - val_loss: 0.5769 - val_accuracy: 0.8019
# Epoch 9/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.5791 - accuracy: 0.8012 - val_loss: 0.5571 - val_accuracy: 0.8087
# Epoch 10/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.5622 - accuracy: 0.8057 - val_loss: 0.5537 - val_accuracy: 0.8105
# Epoch 11/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.5475 - accuracy: 0.8103 - val_loss: 0.5261 - val_accuracy: 0.8157
# Epoch 12/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 0.5338 - accuracy: 0.8138 - val_loss: 0.5078 - val_accuracy: 0.8224
# Epoch 13/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 0.5227 - accuracy: 0.8157 - val_loss: 0.5297 - val_accuracy: 0.8152
# Epoch 14/20
# 1250/1250 [==============================] - 17s 13ms/step - loss: 0.5103 - accuracy: 0.8201 - val_loss: 0.5038 - val_accuracy: 0.8227
# Epoch 15/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 0.5014 - accuracy: 0.8218 - val_loss: 0.5097 - val_accuracy: 0.8196
# Epoch 16/20
# 1250/1250 [==============================] - 18s 14ms/step - loss: 0.4964 - accuracy: 0.8245 - val_loss: 0.4956 - val_accuracy: 0.8238
# Epoch 17/20
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.4834 - accuracy: 0.8267 - val_loss: 0.4878 - val_accuracy: 0.8239
# Epoch 18/20
# 1250/1250 [==============================] - 18s 14ms/step - loss: 0.4782 - accuracy: 0.8282 - val_loss: 0.4854 - val_accuracy: 0.8277
# Epoch 19/20
# 1250/1250 [==============================] - 33s 26ms/step - loss: 0.4733 - accuracy: 0.8299 - val_loss: 0.4710 - val_accuracy: 0.8314
# Epoch 20/20
# 1250/1250 [==============================] - 17s 14ms/step - loss: 0.4651 - accuracy: 0.8325 - val_loss: 0.4762 - val_accuracy: 0.8296

# %% [markdown]
# # Evaluation and Comparison

# %%
# Predict classes cnn
y_pred_cnn = np.argmax(model_cnn_best.predict(x_test_cnn), axis=1)
# Calculate accuracy cnn
accuracy_cnn = accuracy_score(y_test, y_pred_cnn)
print(f"CNN Test Accuracy: {accuracy_cnn:.4f}")
# Out:
# 625/625 [==============================] - 1s 953us/step
# CNN Test Accuracy: 0.8457

# %%
# Predict classes rnn
y_pred_rnn = np.argmax(best_rnn.predict(x_test_rnn), axis=1)
# Calculate accuracy rnn
accuracy_rnn = accuracy_score(y_test, y_pred_rnn)
print(f"RNN Test Accuracy: {accuracy_rnn:.4f}")
# Out:
# 625/625 [==============================] - 3s 4ms/step
# RNN Test Accuracy: 0.8326

# %%
# Predict classes vit
y_pred_vit = np.argmax(final_model_vit.predict(x_test_vit), axis=1)
# Calculate accuracy vit
accuracy_rnn = accuracy_score(y_test, y_pred_vit)
print(f"VIT Test Accuracy: {accuracy_rnn:.4f}")
# Out:
# 625/625 [==============================] - 2s 3ms/step
# VIT Test Accuracy: 0.8278

# %% [markdown]
# ### Accuracy

# %%
plt.figure(figsize=(10, 6))
    
# CNN
plt.plot(history_cnn.history['accuracy'], label='CNN Train Accuracy', color='#1f77b4')
plt.plot(history_cnn.history['val_accuracy'], label='CNN Val Accuracy', color='lightskyblue')

# RNN
plt.plot(history_rnn.history['accuracy'], label='RNN Train Accuracy', color='#ff7f0e')
plt.plot(history_rnn.history['val_accuracy'], label='RNN Val Accuracy', color='#ffdd57')

# ViT
plt.plot(history_vit.history['accuracy'], label='ViT Train Accuracy', color='green')
plt.plot(history_vit.history['val_accuracy'], label='ViT Val Accuracy', color='lightgreen')

plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Precision and Recall

# %%
def calculate_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=1)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=1)
    return accuracy, precision, recall

acc_cnn, prec_cnn, rec_cnn = calculate_metrics(y_test, y_pred_cnn)
acc_rnn, prec_rnn, rec_rnn = calculate_metrics(y_test, y_pred_rnn)
acc_vit, prec_vit, rec_vit = calculate_metrics(y_test, y_pred_vit)

metrics = ['Accuracy', 'Precision', 'Recall']
cnn_metrics = [acc_cnn, prec_cnn, rec_cnn]
rnn_metrics = [acc_rnn, prec_rnn, rec_rnn]
vit_metrics = [acc_vit, prec_vit, rec_vit]

x = np.arange(len(metrics))
width = 0.2
colors_cnn = ['#1f77b4'] * 3
colors_rnn = ['#ff7f0e'] * 3
colors_vit = ['#2ca02c'] * 3

fig, ax = plt.subplots(figsize=(10, 6))
bars_cnn = ax.bar(x - width, cnn_metrics, width, label='CNN', color=colors_cnn)
bars_rnn = ax.bar(x, rnn_metrics, width, label='RNN', color=colors_rnn)
bars_vit = ax.bar(x + width, vit_metrics, width, label='ViT', color=colors_vit)

for bar in bars_cnn:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
for bar in bars_rnn:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
for bar in bars_vit:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, round(yval, 4), ha='center', va='bottom')

ax.set_ylim(0.5, 1.0)
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Accuracy, Precision, and Recall')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend(loc='best')

plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
cm_cnn = confusion_matrix(y_test, y_pred_cnn)
cm_rnn = confusion_matrix(y_test, y_pred_rnn)
cm_vit = confusion_matrix(y_test, y_pred_vit)

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.heatmap(cm_cnn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('CNN Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

sns.heatmap(cm_rnn, annot=True, fmt='d', cmap='Oranges', ax=axes[1])
axes[1].set_title('RNN Confusion Matrix')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('True')

sns.heatmap(cm_vit, annot=True, fmt='d', cmap='Greens', ax=axes[2])
axes[2].set_title('ViT Confusion Matrix')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('True')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Final Model

# %%
print(f"The Best Model is: CNN, and its Test Accuracy: {accuracy_cnn:.4f}")
# Out:
# The Best Model is: CNN, and its Test Accuracy: 0.8457
